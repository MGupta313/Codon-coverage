# %% [markdown]
# # DHFR

# %% [markdown]
# ### Individual samples - df

# %%
import os
import re
import pandas as pd

pd.set_option("display.max_rows", None, "display.max_columns", None)


data = {'gene':[], 'coverage':[], 'snp':[], 'method':[]}

snp_dhfr_list = ['N51I', 'C59R', 'S108N']
snp_pos_list =[]
for i in range(len(snp_dhfr_list)):
    test_string = snp_dhfr_list[i]
    snp_position = ''.join(filter(lambda i: i.isdigit(), test_string))
    snp_pos_list.append(int(snp_position))
# print(snp_pos_list)  
    
samples_not_included =[]

cov_directory = r'/Users/mansi/Desktop/Haiti/Individual/Codon_coverage/PfDHFR/Coverage_results/avg_cov/'
for filename in os.listdir(cov_directory):
    if re.search(pattern = "^(avg)", string = filename):
        filepath = os.path.join(cov_directory, filename)
        sample_num = filename[4:10].split("P")[0]
#         print(sample_num)
    
        df_dhfr = pd.read_csv(filepath, sep="\t")
        df_codon_pos_list = list(df_dhfr.Codon_pos)
        for i in range(len(snp_dhfr_list)):
            test_string = snp_dhfr_list[i]
            snp_position = int(''.join(filter(lambda i: i.isdigit(), test_string)))
            df_snp_pos = snp_position - 1
            if df_snp_pos in df_codon_pos_list:
                cov_val = df_dhfr.at[df_snp_pos, "Codon_coverage"]
                data['coverage'].append(cov_val)
#                 data['sample'].append(sample_num)
                data['gene'].append('dhfr')
                data['method'].append('individual')
                data['snp'].append(test_string)
            else:
                samples_not_included.append(sample_num)



snp_df1 = pd.DataFrame(data)

snp_df_individ = snp_df1
snp_df_individ
# Out:
#      gene  coverage    snp      method
# 0    dhfr       333   N51I  individual
# 1    dhfr       303   C59R  individual
# 2    dhfr       288  S108N  individual
# 3    dhfr        95   N51I  individual
# 4    dhfr        81   C59R  individual
# 5    dhfr       105  S108N  individual
# 6    dhfr       723   N51I  individual
# 7    dhfr       615   C59R  individual
# 8    dhfr       466  S108N  individual
# 9    dhfr       298   N51I  individual
# 10   dhfr       282   C59R  individual
# 11   dhfr       252  S108N  individual
# 12   dhfr       645   N51I  individual
# 13   dhfr       499   C59R  individual
# 14   dhfr       401  S108N  individual
# 15   dhfr       590   N51I  individual
# 16   dhfr       516   C59R  individual
# 17   dhfr       482  S108N  individual
# 18   dhfr       714   N51I  individual
# 19   dhfr       642   C59R  individual
# 20   dhfr       564  S108N  individual
# 21   dhfr       263   N51I  individual
# 22   dhfr       243   C59R  individual
# 23   dhfr       210  S108N  individual
# 24   dhfr        44   N51I  individual
# 25   dhfr        37   C59R  individual
# 26   dhfr        26  S108N  individual
# 27   dhfr       584   N51I  individual
# 28   dhfr       506   C59R  individual
# 29   dhfr       464  S108N  individual
# 30   dhfr       351   N51I  individual
# 31   dhfr       328   C59R  individual
# 32   dhfr       303  S108N  individual
# 33   dhfr        87   N51I  individual
# 34   dhfr        81   C59R  individual
# 35   dhfr        67  S108N  individual
# 36   dhfr        40   N51I  individual
# 37   dhfr        32   C59R  individual
# 38   dhfr        44  S108N  individual
# 39   dhfr       132   N51I  individual
# 40   dhfr       124   C59R  individual
# 41   dhfr       150  S108N  individual
# 42   dhfr       473   N51I  individual
# 43   dhfr       399   C59R  individual
# 44   dhfr       334  S108N  individual
# 45   dhfr       418   N51I  individual
# 46   dhfr       357   C59R  individual
# 47   dhfr       340  S108N  individual
# 48   dhfr       293   N51I  individual
# 49   dhfr       288   C59R  individual
# 50   dhfr       277  S108N  individual
# 51   dhfr       423   N51I  individual
# 52   dhfr       357   C59R  individual
# 53   dhfr       322  S108N  individual
# 54   dhfr       717   N51I  individual
# 55   dhfr       587   C59R  individual
# 56   dhfr       382  S108N  individual
# 57   dhfr       213   N51I  individual
# 58   dhfr       191   C59R  individual
# 59   dhfr       139  S108N  individual
# 60   dhfr       209   N51I  individual
# 61   dhfr       196   C59R  individual
# 62   dhfr       174  S108N  individual
# 63   dhfr       321   N51I  individual
# 64   dhfr       267   C59R  individual
# 65   dhfr       231  S108N  individual
# 66   dhfr      1064   N51I  individual
# 67   dhfr       835   C59R  individual
# 68   dhfr       621  S108N  individual
# 69   dhfr       271   N51I  individual
# 70   dhfr       224   C59R  individual
# 71   dhfr       216  S108N  individual
# 72   dhfr       166   N51I  individual
# 73   dhfr       139   C59R  individual
# 74   dhfr       131  S108N  individual
# 75   dhfr       108   N51I  individual
# 76   dhfr        97   C59R  individual
# 77   dhfr        89  S108N  individual
# 78   dhfr       686   N51I  individual
# 79   dhfr       560   C59R  individual
# 80   dhfr       449  S108N  individual
# 81   dhfr        62   N51I  individual
# 82   dhfr        65   C59R  individual
# 83   dhfr        44  S108N  individual
# 84   dhfr       409   N51I  individual
# 85   dhfr       341   C59R  individual
# 86   dhfr       292  S108N  individual
# 87   dhfr       342   N51I  individual
# 88   dhfr       282   C59R  individual
# 89   dhfr       230  S108N  individual
# 90   dhfr       169   N51I  individual
# 91   dhfr       144   C59R  individual
# 92   dhfr       183  S108N  individual
# 93   dhfr       242   N51I  individual
# 94   dhfr       190   C59R  individual
# 95   dhfr       153  S108N  individual
# 96   dhfr        10   N51I  individual
# 97   dhfr         8   C59R  individual
# 98   dhfr         6  S108N  individual
# 99   dhfr        18   N51I  individual
# 100  dhfr        18   C59R  individual
# 101  dhfr        18  S108N  individual
# 102  dhfr        21   N51I  individual
# 103  dhfr        14   C59R  individual
# 104  dhfr         3  S108N  individual
# 105  dhfr       538   N51I  individual
# 106  dhfr       509   C59R  individual
# 107  dhfr       535  S108N  individual
# 108  dhfr       254   N51I  individual
# 109  dhfr       193   C59R  individual
# 110  dhfr       136  S108N  individual
# 111  dhfr       577   N51I  individual
# 112  dhfr       472   C59R  individual
# 113  dhfr       411  S108N  individual
# 114  dhfr       575   N51I  individual
# 115  dhfr       524   C59R  individual
# 116  dhfr       455  S108N  individual
# 117  dhfr       200   N51I  individual
# 118  dhfr       169   C59R  individual
# 119  dhfr       132  S108N  individual
# 120  dhfr       310   N51I  individual
# 121  dhfr       265   C59R  individual
# 122  dhfr       257  S108N  individual
# 123  dhfr        21   N51I  individual
# 124  dhfr        16   C59R  individual
# 125  dhfr        14  S108N  individual
# 126  dhfr       509   N51I  individual
# 127  dhfr       380   C59R  individual
# 128  dhfr       323  S108N  individual
# 129  dhfr       688   N51I  individual
# 130  dhfr       573   C59R  individual
# 131  dhfr       427  S108N  individual
# 132  dhfr       152   N51I  individual
# 133  dhfr       146   C59R  individual
# 134  dhfr       117  S108N  individual
# 135  dhfr       861   N51I  individual
# 136  dhfr       731   C59R  individual
# 137  dhfr       585  S108N  individual
# 138  dhfr        83   N51I  individual
# 139  dhfr        61   C59R  individual
# 140  dhfr        49  S108N  individual
# 141  dhfr       203   N51I  individual
# 142  dhfr       188   C59R  individual
# 143  dhfr       172  S108N  individual
# 144  dhfr       603   N51I  individual
# 145  dhfr       411   C59R  individual
# 146  dhfr       260  S108N  individual
# 147  dhfr        34   N51I  individual
# 148  dhfr        32   C59R  individual
# 149  dhfr        17  S108N  individual
# 150  dhfr        50   N51I  individual
# 151  dhfr        41   C59R  individual
# 152  dhfr        42  S108N  individual
# 153  dhfr       123   N51I  individual
# 154  dhfr       106   C59R  individual
# 155  dhfr        87  S108N  individual
# 156  dhfr        73   N51I  individual
# 157  dhfr        68   C59R  individual
# 158  dhfr        43  S108N  individual
# 159  dhfr       340   N51I  individual
# 160  dhfr       289   C59R  individual
# 161  dhfr       278  S108N  individual
# 162  dhfr      1196   N51I  individual
# 163  dhfr      1007   C59R  individual
# 164  dhfr       876  S108N  individual
# 165  dhfr       238   N51I  individual
# 166  dhfr       202   C59R  individual
# 167  dhfr       195  S108N  individual
# 168  dhfr       318   N51I  individual
# 169  dhfr       285   C59R  individual
# 170  dhfr       263  S108N  individual
# 171  dhfr       441   N51I  individual
# 172  dhfr       393   C59R  individual
# 173  dhfr       346  S108N  individual
# 174  dhfr        92   N51I  individual
# 175  dhfr        76   C59R  individual
# 176  dhfr        72  S108N  individual
# 177  dhfr        18   N51I  individual
# 178  dhfr        14   C59R  individual
# 179  dhfr        32  S108N  individual
# 180  dhfr       485   N51I  individual
# 181  dhfr       461   C59R  individual
# 182  dhfr       481  S108N  individual
# 183  dhfr       395   N51I  individual
# 184  dhfr       329   C59R  individual
# 185  dhfr       301  S108N  individual
# 186  dhfr       597   N51I  individual
# 187  dhfr       554   C59R  individual
# 188  dhfr       604  S108N  individual
# 189  dhfr       497   N51I  individual
# 190  dhfr       459   C59R  individual
# 191  dhfr       405  S108N  individual
# 192  dhfr       354   N51I  individual
# 193  dhfr       315   C59R  individual
# 194  dhfr       277  S108N  individual
# 195  dhfr       672   N51I  individual
# 196  dhfr       616   C59R  individual
# 197  dhfr       540  S108N  individual
# 198  dhfr       426   N51I  individual
# 199  dhfr       371   C59R  individual
# 200  dhfr       317  S108N  individual
# 201  dhfr       107   N51I  individual
# 202  dhfr        86   C59R  individual
# 203  dhfr        88  S108N  individual
# 204  dhfr       241   N51I  individual
# 205  dhfr       212   C59R  individual
# 206  dhfr       194  S108N  individual
# 207  dhfr        26   N51I  individual
# 208  dhfr        23   C59R  individual
# 209  dhfr        23  S108N  individual
# 210  dhfr       352   N51I  individual
# 211  dhfr       320   C59R  individual
# 212  dhfr       346  S108N  individual
# 213  dhfr       319   N51I  individual
# 214  dhfr       296   C59R  individual
# 215  dhfr       278  S108N  individual
# 216  dhfr       346   N51I  individual
# 217  dhfr       313   C59R  individual
# 218  dhfr       306  S108N  individual
# 219  dhfr       687   N51I  individual
# 220  dhfr       572   C59R  individual
# 221  dhfr       491  S108N  individual
# 222  dhfr       361   N51I  individual
# 223  dhfr       308   C59R  individual
# 224  dhfr       271  S108N  individual
# 225  dhfr       107   N51I  individual
# 226  dhfr        97   C59R  individual
# 227  dhfr        57  S108N  individual
# 228  dhfr       624   N51I  individual
# 229  dhfr       521   C59R  individual
# 230  dhfr       378  S108N  individual
# 231  dhfr        23   N51I  individual
# 232  dhfr        22   C59R  individual
# 233  dhfr        18  S108N  individual
# 234  dhfr       225   N51I  individual
# 235  dhfr       207   C59R  individual
# 236  dhfr       186  S108N  individual
# 237  dhfr       158   N51I  individual
# 238  dhfr       138   C59R  individual
# 239  dhfr        92  S108N  individual
# 240  dhfr       445   N51I  individual
# 241  dhfr       394   C59R  individual
# 242  dhfr       310  S108N  individual
# 243  dhfr       545   N51I  individual
# 244  dhfr       486   C59R  individual
# 245  dhfr       409  S108N  individual
# 246  dhfr       554   N51I  individual
# 247  dhfr       481   C59R  individual
# 248  dhfr       434  S108N  individual
# 249  dhfr       122   N51I  individual
# 250  dhfr       109   C59R  individual
# 251  dhfr        94  S108N  individual
# 252  dhfr        94   N51I  individual
# 253  dhfr        73   C59R  individual
# 254  dhfr        85  S108N  individual
# 255  dhfr       335   N51I  individual
# 256  dhfr       273   C59R  individual
# 257  dhfr       239  S108N  individual
# 258  dhfr       464   N51I  individual
# 259  dhfr       396   C59R  individual
# 260  dhfr       312  S108N  individual
# 261  dhfr        89   N51I  individual
# 262  dhfr        82   C59R  individual
# 263  dhfr        67  S108N  individual

# %% [markdown]
# ### Pooled samples - df

# %%
import os
import re
import pandas as pd

pd.set_option("display.max_rows", None, "display.max_columns", None)


data = {'gene':[], 'coverage':[], 'snp':[], 'method':[]}

snp_dhfr_list = ['N51I', 'C59R', 'S108N']
snp_pos_list =[]
for i in range(len(snp_dhfr_list)):
    test_string = snp_dhfr_list[i]
    snp_position = ''.join(filter(lambda i: i.isdigit(), test_string))
    snp_pos_list.append(int(snp_position))
# print(snp_pos_list)  
    
samples_not_included =[]

cov_directory = r'/Users/mansi/Desktop/Haiti/Pooled/Codon_coverage/PfDHFR/Coverage_results/avg_cov/'
for filename in os.listdir(cov_directory):
    if re.search(pattern = "^(avg)", string = filename):
        filepath = os.path.join(cov_directory, filename)
        sample_num = filename[4:7].split("P")[0]
#         print(sample_num)
    
        df_dhfr = pd.read_csv(filepath, sep="\t")
        df_codon_pos_list = list(df_dhfr.Codon_pos)
        for i in range(len(snp_dhfr_list)):
            test_string = snp_dhfr_list[i]
            snp_position = int(''.join(filter(lambda i: i.isdigit(), test_string)))
            df_snp_pos = snp_position - 1
            if df_snp_pos in df_codon_pos_list:
                cov_val = df_dhfr.at[df_snp_pos, "Codon_coverage"]
                data['coverage'].append(cov_val)
#                 data['sample'].append(sample_num)
                data['gene'].append('dhfr')
                data['method'].append('pooled')
                data['snp'].append(test_string)
            else:
                samples_not_included.append(sample_num)



snp_df2 = pd.DataFrame(data)

snp_df_pooled = snp_df2
snp_df_pooled
# Out:
#     gene  coverage    snp  method
# 0   dhfr      1065   N51I  pooled
# 1   dhfr       986   C59R  pooled
# 2   dhfr       991  S108N  pooled
# 3   dhfr         2   N51I  pooled
# 4   dhfr         2   C59R  pooled
# 5   dhfr         2  S108N  pooled
# 6   dhfr       540   N51I  pooled
# 7   dhfr       464   C59R  pooled
# 8   dhfr       409  S108N  pooled
# 9   dhfr      4162   N51I  pooled
# 10  dhfr      3741   C59R  pooled
# 11  dhfr      3383  S108N  pooled
# 12  dhfr      1314   N51I  pooled
# 13  dhfr      1182   C59R  pooled
# 14  dhfr      1322  S108N  pooled
# 15  dhfr      1287   N51I  pooled
# 16  dhfr      1161   C59R  pooled
# 17  dhfr      1222  S108N  pooled
# 18  dhfr      1032   N51I  pooled
# 19  dhfr       910   C59R  pooled
# 20  dhfr       992  S108N  pooled
# 21  dhfr      3343   N51I  pooled
# 22  dhfr      2939   C59R  pooled
# 23  dhfr      2677  S108N  pooled
# 24  dhfr      1087   N51I  pooled
# 25  dhfr      1035   C59R  pooled
# 26  dhfr      1068  S108N  pooled
# 27  dhfr      1111   N51I  pooled
# 28  dhfr       962   C59R  pooled
# 29  dhfr       896  S108N  pooled

# %% [markdown]
# ### Appending pooled df to individual df

# %%
df_dhfr_fin = snp_df_individ.append(snp_df_pooled, ignore_index=True)
df_dhfr_fin
# Out:
#      gene  coverage    snp      method
# 0    dhfr       333   N51I  individual
# 1    dhfr       303   C59R  individual
# 2    dhfr       288  S108N  individual
# 3    dhfr        95   N51I  individual
# 4    dhfr        81   C59R  individual
# 5    dhfr       105  S108N  individual
# 6    dhfr       723   N51I  individual
# 7    dhfr       615   C59R  individual
# 8    dhfr       466  S108N  individual
# 9    dhfr       298   N51I  individual
# 10   dhfr       282   C59R  individual
# 11   dhfr       252  S108N  individual
# 12   dhfr       645   N51I  individual
# 13   dhfr       499   C59R  individual
# 14   dhfr       401  S108N  individual
# 15   dhfr       590   N51I  individual
# 16   dhfr       516   C59R  individual
# 17   dhfr       482  S108N  individual
# 18   dhfr       714   N51I  individual
# 19   dhfr       642   C59R  individual
# 20   dhfr       564  S108N  individual
# 21   dhfr       263   N51I  individual
# 22   dhfr       243   C59R  individual
# 23   dhfr       210  S108N  individual
# 24   dhfr        44   N51I  individual
# 25   dhfr        37   C59R  individual
# 26   dhfr        26  S108N  individual
# 27   dhfr       584   N51I  individual
# 28   dhfr       506   C59R  individual
# 29   dhfr       464  S108N  individual
# 30   dhfr       351   N51I  individual
# 31   dhfr       328   C59R  individual
# 32   dhfr       303  S108N  individual
# 33   dhfr        87   N51I  individual
# 34   dhfr        81   C59R  individual
# 35   dhfr        67  S108N  individual
# 36   dhfr        40   N51I  individual
# 37   dhfr        32   C59R  individual
# 38   dhfr        44  S108N  individual
# 39   dhfr       132   N51I  individual
# 40   dhfr       124   C59R  individual
# 41   dhfr       150  S108N  individual
# 42   dhfr       473   N51I  individual
# 43   dhfr       399   C59R  individual
# 44   dhfr       334  S108N  individual
# 45   dhfr       418   N51I  individual
# 46   dhfr       357   C59R  individual
# 47   dhfr       340  S108N  individual
# 48   dhfr       293   N51I  individual
# 49   dhfr       288   C59R  individual
# 50   dhfr       277  S108N  individual
# 51   dhfr       423   N51I  individual
# 52   dhfr       357   C59R  individual
# 53   dhfr       322  S108N  individual
# 54   dhfr       717   N51I  individual
# 55   dhfr       587   C59R  individual
# 56   dhfr       382  S108N  individual
# 57   dhfr       213   N51I  individual
# 58   dhfr       191   C59R  individual
# 59   dhfr       139  S108N  individual
# 60   dhfr       209   N51I  individual
# 61   dhfr       196   C59R  individual
# 62   dhfr       174  S108N  individual
# 63   dhfr       321   N51I  individual
# 64   dhfr       267   C59R  individual
# 65   dhfr       231  S108N  individual
# 66   dhfr      1064   N51I  individual
# 67   dhfr       835   C59R  individual
# 68   dhfr       621  S108N  individual
# 69   dhfr       271   N51I  individual
# 70   dhfr       224   C59R  individual
# 71   dhfr       216  S108N  individual
# 72   dhfr       166   N51I  individual
# 73   dhfr       139   C59R  individual
# 74   dhfr       131  S108N  individual
# 75   dhfr       108   N51I  individual
# 76   dhfr        97   C59R  individual
# 77   dhfr        89  S108N  individual
# 78   dhfr       686   N51I  individual
# 79   dhfr       560   C59R  individual
# 80   dhfr       449  S108N  individual
# 81   dhfr        62   N51I  individual
# 82   dhfr        65   C59R  individual
# 83   dhfr        44  S108N  individual
# 84   dhfr       409   N51I  individual
# 85   dhfr       341   C59R  individual
# 86   dhfr       292  S108N  individual
# 87   dhfr       342   N51I  individual
# 88   dhfr       282   C59R  individual
# 89   dhfr       230  S108N  individual
# 90   dhfr       169   N51I  individual
# 91   dhfr       144   C59R  individual
# 92   dhfr       183  S108N  individual
# 93   dhfr       242   N51I  individual
# 94   dhfr       190   C59R  individual
# 95   dhfr       153  S108N  individual
# 96   dhfr        10   N51I  individual
# 97   dhfr         8   C59R  individual
# 98   dhfr         6  S108N  individual
# 99   dhfr        18   N51I  individual
# 100  dhfr        18   C59R  individual
# 101  dhfr        18  S108N  individual
# 102  dhfr        21   N51I  individual
# 103  dhfr        14   C59R  individual
# 104  dhfr         3  S108N  individual
# 105  dhfr       538   N51I  individual
# 106  dhfr       509   C59R  individual
# 107  dhfr       535  S108N  individual
# 108  dhfr       254   N51I  individual
# 109  dhfr       193   C59R  individual
# 110  dhfr       136  S108N  individual
# 111  dhfr       577   N51I  individual
# 112  dhfr       472   C59R  individual
# 113  dhfr       411  S108N  individual
# 114  dhfr       575   N51I  individual
# 115  dhfr       524   C59R  individual
# 116  dhfr       455  S108N  individual
# 117  dhfr       200   N51I  individual
# 118  dhfr       169   C59R  individual
# 119  dhfr       132  S108N  individual
# 120  dhfr       310   N51I  individual
# 121  dhfr       265   C59R  individual
# 122  dhfr       257  S108N  individual
# 123  dhfr        21   N51I  individual
# 124  dhfr        16   C59R  individual
# 125  dhfr        14  S108N  individual
# 126  dhfr       509   N51I  individual
# 127  dhfr       380   C59R  individual
# 128  dhfr       323  S108N  individual
# 129  dhfr       688   N51I  individual
# 130  dhfr       573   C59R  individual
# 131  dhfr       427  S108N  individual
# 132  dhfr       152   N51I  individual
# 133  dhfr       146   C59R  individual
# 134  dhfr       117  S108N  individual
# 135  dhfr       861   N51I  individual
# 136  dhfr       731   C59R  individual
# 137  dhfr       585  S108N  individual
# 138  dhfr        83   N51I  individual
# 139  dhfr        61   C59R  individual
# 140  dhfr        49  S108N  individual
# 141  dhfr       203   N51I  individual
# 142  dhfr       188   C59R  individual
# 143  dhfr       172  S108N  individual
# 144  dhfr       603   N51I  individual
# 145  dhfr       411   C59R  individual
# 146  dhfr       260  S108N  individual
# 147  dhfr        34   N51I  individual
# 148  dhfr        32   C59R  individual
# 149  dhfr        17  S108N  individual
# 150  dhfr        50   N51I  individual
# 151  dhfr        41   C59R  individual
# 152  dhfr        42  S108N  individual
# 153  dhfr       123   N51I  individual
# 154  dhfr       106   C59R  individual
# 155  dhfr        87  S108N  individual
# 156  dhfr        73   N51I  individual
# 157  dhfr        68   C59R  individual
# 158  dhfr        43  S108N  individual
# 159  dhfr       340   N51I  individual
# 160  dhfr       289   C59R  individual
# 161  dhfr       278  S108N  individual
# 162  dhfr      1196   N51I  individual
# 163  dhfr      1007   C59R  individual
# 164  dhfr       876  S108N  individual
# 165  dhfr       238   N51I  individual
# 166  dhfr       202   C59R  individual
# 167  dhfr       195  S108N  individual
# 168  dhfr       318   N51I  individual
# 169  dhfr       285   C59R  individual
# 170  dhfr       263  S108N  individual
# 171  dhfr       441   N51I  individual
# 172  dhfr       393   C59R  individual
# 173  dhfr       346  S108N  individual
# 174  dhfr        92   N51I  individual
# 175  dhfr        76   C59R  individual
# 176  dhfr        72  S108N  individual
# 177  dhfr        18   N51I  individual
# 178  dhfr        14   C59R  individual
# 179  dhfr        32  S108N  individual
# 180  dhfr       485   N51I  individual
# 181  dhfr       461   C59R  individual
# 182  dhfr       481  S108N  individual
# 183  dhfr       395   N51I  individual
# 184  dhfr       329   C59R  individual
# 185  dhfr       301  S108N  individual
# 186  dhfr       597   N51I  individual
# 187  dhfr       554   C59R  individual
# 188  dhfr       604  S108N  individual
# 189  dhfr       497   N51I  individual
# 190  dhfr       459   C59R  individual
# 191  dhfr       405  S108N  individual
# 192  dhfr       354   N51I  individual
# 193  dhfr       315   C59R  individual
# 194  dhfr       277  S108N  individual
# 195  dhfr       672   N51I  individual
# 196  dhfr       616   C59R  individual
# 197  dhfr       540  S108N  individual
# 198  dhfr       426   N51I  individual
# 199  dhfr       371   C59R  individual
# 200  dhfr       317  S108N  individual
# 201  dhfr       107   N51I  individual
# 202  dhfr        86   C59R  individual
# 203  dhfr        88  S108N  individual
# 204  dhfr       241   N51I  individual
# 205  dhfr       212   C59R  individual
# 206  dhfr       194  S108N  individual
# 207  dhfr        26   N51I  individual
# 208  dhfr        23   C59R  individual
# 209  dhfr        23  S108N  individual
# 210  dhfr       352   N51I  individual
# 211  dhfr       320   C59R  individual
# 212  dhfr       346  S108N  individual
# 213  dhfr       319   N51I  individual
# 214  dhfr       296   C59R  individual
# 215  dhfr       278  S108N  individual
# 216  dhfr       346   N51I  individual
# 217  dhfr       313   C59R  individual
# 218  dhfr       306  S108N  individual
# 219  dhfr       687   N51I  individual
# 220  dhfr       572   C59R  individual
# 221  dhfr       491  S108N  individual
# 222  dhfr       361   N51I  individual
# 223  dhfr       308   C59R  individual
# 224  dhfr       271  S108N  individual
# 225  dhfr       107   N51I  individual
# 226  dhfr        97   C59R  individual
# 227  dhfr        57  S108N  individual
# 228  dhfr       624   N51I  individual
# 229  dhfr       521   C59R  individual
# 230  dhfr       378  S108N  individual
# 231  dhfr        23   N51I  individual
# 232  dhfr        22   C59R  individual
# 233  dhfr        18  S108N  individual
# 234  dhfr       225   N51I  individual
# 235  dhfr       207   C59R  individual
# 236  dhfr       186  S108N  individual
# 237  dhfr       158   N51I  individual
# 238  dhfr       138   C59R  individual
# 239  dhfr        92  S108N  individual
# 240  dhfr       445   N51I  individual
# 241  dhfr       394   C59R  individual
# 242  dhfr       310  S108N  individual
# 243  dhfr       545   N51I  individual
# 244  dhfr       486   C59R  individual
# 245  dhfr       409  S108N  individual
# 246  dhfr       554   N51I  individual
# 247  dhfr       481   C59R  individual
# 248  dhfr       434  S108N  individual
# 249  dhfr       122   N51I  individual
# 250  dhfr       109   C59R  individual
# 251  dhfr        94  S108N  individual
# 252  dhfr        94   N51I  individual
# 253  dhfr        73   C59R  individual
# 254  dhfr        85  S108N  individual
# 255  dhfr       335   N51I  individual
# 256  dhfr       273   C59R  individual
# 257  dhfr       239  S108N  individual
# 258  dhfr       464   N51I  individual
# 259  dhfr       396   C59R  individual
# 260  dhfr       312  S108N  individual
# 261  dhfr        89   N51I  individual
# 262  dhfr        82   C59R  individual
# 263  dhfr        67  S108N  individual
# 264  dhfr      1065   N51I      pooled
# 265  dhfr       986   C59R      pooled
# 266  dhfr       991  S108N      pooled
# 267  dhfr         2   N51I      pooled
# 268  dhfr         2   C59R      pooled
# 269  dhfr         2  S108N      pooled
# 270  dhfr       540   N51I      pooled
# 271  dhfr       464   C59R      pooled
# 272  dhfr       409  S108N      pooled
# 273  dhfr      4162   N51I      pooled
# 274  dhfr      3741   C59R      pooled
# 275  dhfr      3383  S108N      pooled
# 276  dhfr      1314   N51I      pooled
# 277  dhfr      1182   C59R      pooled
# 278  dhfr      1322  S108N      pooled
# 279  dhfr      1287   N51I      pooled
# 280  dhfr      1161   C59R      pooled
# 281  dhfr      1222  S108N      pooled
# 282  dhfr      1032   N51I      pooled
# 283  dhfr       910   C59R      pooled
# 284  dhfr       992  S108N      pooled
# 285  dhfr      3343   N51I      pooled
# 286  dhfr      2939   C59R      pooled
# 287  dhfr      2677  S108N      pooled
# 288  dhfr      1087   N51I      pooled
# 289  dhfr      1035   C59R      pooled
# 290  dhfr      1068  S108N      pooled
# 291  dhfr      1111   N51I      pooled
# 292  dhfr       962   C59R      pooled
# 293  dhfr       896  S108N      pooled

# %% [markdown]
# ### Plotting

# %%
import seaborn as sns
import matplotlib.pyplot as plt

my_pal = {"pooled":"#ef9300", "individual":"#32b67a"}

dpi = 80   
fig = plt.figure(1, figsize=(12, 9), dpi = dpi)
ax = fig.add_subplot(111)    
sns.set(rc={'figure.figsize':(12,10)}, style="whitegrid")

bp = sns.violinplot(x="snp", y="coverage", hue = "method", hue_order=['pooled', 'individual'], data = df_dhfr_fin, width = 1.2, cut = 0, palette=my_pal)

ax.set_title('Codon coverge for - PfDHFR', fontweight ='bold', fontsize = 14)
ax.set_ylabel('Codon coverage', fontweight ='bold', labelpad = 10.5)
ax.set_xlabel('SNP', fontweight ='bold', labelpad = 10.5)

plt.show()
outputfile = "/Users/mansi/Desktop/Haiti/Sequence_method_comparison/dhfr-violin.png"
fig.savefig(outputfile, bbox_inches='tight')

# %%
dpi = 80   
fig = plt.figure(1, figsize=(12, 9), dpi = dpi)
ax = fig.add_subplot(111)    
sns.set(rc={'figure.figsize':(12,10)}, style="whitegrid")

bp = sns.boxenplot(x="snp", y="coverage", hue = "method", hue_order=['pooled', 'individual'], data = df_dhfr_fin, palette=my_pal)

ax.set_title('Codon coverge for - PfDHFR', fontweight ='bold', fontsize = 14)
ax.set_ylabel('Codon coverage', fontweight ='bold', labelpad = 10.5)
ax.set_xlabel('SNP', fontweight ='bold', labelpad = 10.5)

plt.show()
outputfile = "/Users/mansi/Desktop/Haiti/Sequence_method_comparison/dhfr-boxen.png"
fig.savefig(outputfile, bbox_inches='tight')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
my_pal = {"pooled":"#ef9300", "individual":"#32b67a"}


bp = sns.catplot(x="snp", y="coverage", hue = 'method', data=df_dhfr_fin, height=6, aspect=3, palette = my_pal)
title = 'PfDHFR - Sequence method comparison'
bp.fig.suptitle(title)

plt.show()
# display(data_df.describe())

outputfile = "/Users/mansi/Desktop/Haiti/Sequence_method_comparison/dhfr-catplot.png"
bp.savefig(outputfile, bbox_inches='tight')

# %% [markdown]
# # MDR1

# %%
import os
import re
import pandas as pd

pd.set_option("display.max_rows", None, "display.max_columns", None)


data = {'gene':[], 'coverage':[], 'snp':[], 'method':[]}

snp_dhfr_list = ['Y184F', 'S1034C', 'N1042D', 'D1246Y']
snp_pos_list =[]
for i in range(len(snp_dhfr_list)):
    test_string = snp_dhfr_list[i]
    snp_position = ''.join(filter(lambda i: i.isdigit(), test_string))
    snp_pos_list.append(int(snp_position))
# print(snp_pos_list)  
    
samples_not_included =[]

cov_directory = r'/Users/mansi/Desktop/Haiti/Individual/Codon_coverage/PfMDR1/Coverage_results/avg_cov/'
for filename in os.listdir(cov_directory):
    if re.search(pattern = "^(avg)", string = filename):
        filepath = os.path.join(cov_directory, filename)
        sample_num = filename[4:10].split("P")[0]
#         print(sample_num)
    
        temp_df = pd.read_csv(filepath, sep="\t")
        df_codon_pos_list = list(temp_df.Codon_pos)
        for i in range(len(snp_dhfr_list)):
            test_string = snp_dhfr_list[i]
            snp_position = int(''.join(filter(lambda i: i.isdigit(), test_string)))
            df_snp_pos = snp_position - 1
            if df_snp_pos in df_codon_pos_list:
                cov_val = temp_df.at[df_snp_pos, "Codon_coverage"]
                data['coverage'].append(cov_val)
#                 data['sample'].append(sample_num)
                data['gene'].append('mdr1')
                data['method'].append('individual')
                data['snp'].append(test_string)
            else:
                samples_not_included.append(sample_num)



snp_df3 = pd.DataFrame(data)

df_ind_mdr1 = snp_df3

########################################################################
######For pooled samples#########

import os
import re
import pandas as pd

pd.set_option("display.max_rows", None, "display.max_columns", None)


data = {'gene':[], 'coverage':[], 'snp':[], 'method':[]}

snp_dhfr_list = ['Y184F', 'S1034C', 'N1042D', 'D1246Y']
snp_pos_list =[]
for i in range(len(snp_dhfr_list)):
    test_string = snp_dhfr_list[i]
    snp_position = ''.join(filter(lambda i: i.isdigit(), test_string))
    snp_pos_list.append(int(snp_position))
# print(snp_pos_list)  
    
samples_not_included =[]

cov_directory = r'/Users/mansi/Desktop/Haiti/Pooled/Codon_coverage/PfMDR1/Coverage_results/avg_cov/'
for filename in os.listdir(cov_directory):
    if re.search(pattern = "^(avg)", string = filename):
        filepath = os.path.join(cov_directory, filename)
        sample_num = filename[4:7].split("P")[0]
#         print(sample_num)
    
        temp_df_mdr1 = pd.read_csv(filepath, sep="\t")
        df_codon_pos_list = list(temp_df_mdr1.Codon_pos)
        for i in range(len(snp_dhfr_list)):
            test_string = snp_dhfr_list[i]
            snp_position = int(''.join(filter(lambda i: i.isdigit(), test_string)))
            df_snp_pos = snp_position - 1
            if df_snp_pos in df_codon_pos_list:
                cov_val = temp_df_mdr1.at[df_snp_pos, "Codon_coverage"]
                data['coverage'].append(cov_val)
#                 data['sample'].append(sample_num)
                data['gene'].append('mdr1')
                data['method'].append('pooled')
                data['snp'].append(test_string)
            else:
                samples_not_included.append(sample_num)



snp_df4 = pd.DataFrame(data)

df_pool_mdr1 = snp_df4

df_mdr1_fin = df_ind_mdr1.append(df_pool_mdr1, ignore_index=True)

# %% [markdown]
# ### Plotting

# %%
dpi = 80   
fig = plt.figure(1, figsize=(12, 9), dpi = dpi)
ax = fig.add_subplot(111)    
sns.set(rc={'figure.figsize':(12,10)}, style="whitegrid")

bp = sns.violinplot(x="snp", y="coverage", hue = "method", hue_order=['pooled', 'individual'], data = df_mdr1_fin, width = 1.2, cut = 0, palette=my_pal)

ax.set_title('Codon coverge for - PfMDR1', fontweight ='bold', fontsize = 14)
ax.set_ylabel('Codon coverage', fontweight ='bold', labelpad = 10.5)
ax.set_xlabel('SNP', fontweight ='bold', labelpad = 10.5)

plt.show()
outputfile = "/Users/mansi/Desktop/Haiti/Sequence_method_comparison/mdr1-violin.png"
fig.savefig(outputfile, bbox_inches='tight')

# %%
dpi = 80   
fig = plt.figure(1, figsize=(12, 9), dpi = dpi)
ax = fig.add_subplot(111)    
sns.set(rc={'figure.figsize':(12,10)}, style="whitegrid")

bp = sns.boxenplot(x="snp", y="coverage", hue = "method", hue_order=['pooled', 'individual'], data = df_mdr1_fin, palette=my_pal)

ax.set_title('Codon coverge for - PfMDR1', fontweight ='bold', fontsize = 14)
ax.set_ylabel('Codon coverage', fontweight ='bold', labelpad = 10.5)
ax.set_xlabel('SNP', fontweight ='bold', labelpad = 10.5)

plt.show()
outputfile = "/Users/mansi/Desktop/Haiti/Sequence_method_comparison/mdr1-boxen.png"
fig.savefig(outputfile, bbox_inches='tight')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
my_pal = {"pooled":"#ef9300", "individual":"#32b67a"}


g= sns.catplot(x="snp", y="coverage", hue = 'method', data=df_mdr1_fin, height=6, aspect=3, palette = my_pal)
title = 'PfMDR1 - Sequence method comparison'
g.fig.suptitle(title)

# plt.show()
# display(data_df.describe())

outputfile = "/Users/mansi/Desktop/Haiti/Sequence_method_comparison/mdr1-catplot.png"
g.savefig(outputfile, bbox_inches='tight')

# %% [markdown]
# # DHPS

# %%
import os
import re
import pandas as pd

pd.set_option("display.max_rows", None, "display.max_columns", None)


data = {'gene':[], 'coverage':[], 'snp':[], 'method':[]}

snp_dhfr_list = ['S436A', 'S436H', 'S436F', 'A437G', 'K540E', 'A581G', 'A613S', 'A613T']
snp_pos_list =[]
for i in range(len(snp_dhfr_list)):
    test_string = snp_dhfr_list[i]
    snp_position = ''.join(filter(lambda i: i.isdigit(), test_string))
    snp_pos_list.append(int(snp_position))
# print(snp_pos_list)  
    
samples_not_included =[]

cov_directory = r'/Users/mansi/Desktop/Haiti/Individual/Codon_coverage/PfDHPS/Coverage_results/avg_cov/'
for filename in os.listdir(cov_directory):
    if re.search(pattern = "^(avg)", string = filename):
        filepath = os.path.join(cov_directory, filename)
        sample_num = filename[4:10].split("P")[0]
#         print(sample_num)
    
        df_dhfr = pd.read_csv(filepath, sep="\t")
        df_codon_pos_list = list(df_dhfr.Codon_pos)
        for i in range(len(snp_dhfr_list)):
            test_string = snp_dhfr_list[i]
            snp_position = int(''.join(filter(lambda i: i.isdigit(), test_string)))
            df_snp_pos = snp_position - 1
            if df_snp_pos in df_codon_pos_list:
                cov_val = df_dhfr.at[df_snp_pos, "Codon_coverage"]
                data['coverage'].append(cov_val)
#                 data['sample'].append(sample_num)
                data['gene'].append('dhps')
                data['method'].append('individual')
                data['snp'].append(test_string)
            else:
                samples_not_included.append(sample_num)



snp_df7 = pd.DataFrame(data)

df_ind_dhps = snp_df7

import os
import re
import pandas as pd

pd.set_option("display.max_rows", None, "display.max_columns", None)


data = {'gene':[], 'coverage':[], 'snp':[], 'method':[]}

snp_dhfr_list = ['S436A', 'S436H', 'S436F', 'A437G', 'K540E', 'A581G', 'A613S', 'A613T']
snp_pos_list =[]
for i in range(len(snp_dhfr_list)):
    test_string = snp_dhfr_list[i]
    snp_position = ''.join(filter(lambda i: i.isdigit(), test_string))
    snp_pos_list.append(int(snp_position))
# print(snp_pos_list)  
    
samples_not_included =[]

cov_directory = r'/Users/mansi/Desktop/Haiti/Pooled/Codon_coverage/PfDHPS/Coverage_results/avg_cov/'
for filename in os.listdir(cov_directory):
    if re.search(pattern = "^(avg)", string = filename):
        filepath = os.path.join(cov_directory, filename)
        sample_num = filename[4:7].split("P")[0]
#         print(sample_num)
    
        temp_df_mdr1 = pd.read_csv(filepath, sep="\t")
        df_codon_pos_list = list(temp_df_mdr1.Codon_pos)
        for i in range(len(snp_dhfr_list)):
            test_string = snp_dhfr_list[i]
            snp_position = int(''.join(filter(lambda i: i.isdigit(), test_string)))
            df_snp_pos = snp_position - 1
            if df_snp_pos in df_codon_pos_list:
                cov_val = temp_df_mdr1.at[df_snp_pos, "Codon_coverage"]
                data['coverage'].append(cov_val)
#                 data['sample'].append(sample_num)
                data['gene'].append('dhps')
                data['method'].append('pooled')
                data['snp'].append(test_string)
            else:
                samples_not_included.append(sample_num)



snp_df8 = pd.DataFrame(data)

df_pool_dhps = snp_df8

df_dhps_fin = df_ind_dhps.append(df_pool_dhps, ignore_index=True)

# %%
dpi = 80   
fig = plt.figure(1, figsize=(12, 9), dpi = dpi)
ax = fig.add_subplot(111)    
sns.set(rc={'figure.figsize':(12,10)}, style="whitegrid")

bp = sns.violinplot(x="snp", y="coverage", hue = "method", hue_order=['pooled', 'individual'], data = df_dhps_fin, width = 1.2, cut = 0, palette=my_pal)

ax.set_title('Codon coverge for - PfDHPS', fontweight ='bold', fontsize = 14)
ax.set_ylabel('Codon coverage', fontweight ='bold', labelpad = 10.5)
ax.set_xlabel('SNP', fontweight ='bold', labelpad = 10.5)

plt.show()
outputfile = "/Users/mansi/Desktop/Haiti/Sequence_method_comparison/dhps-violin.png"
fig.savefig(outputfile, bbox_inches='tight')

# %%
dpi = 80   
fig = plt.figure(1, figsize=(12, 9), dpi = dpi)
ax = fig.add_subplot(111)    
sns.set(rc={'figure.figsize':(12,10)}, style="whitegrid")

bp = sns.boxenplot(x="snp", y="coverage", hue = "method", hue_order=['pooled', 'individual'], data = df_dhps_fin, palette=my_pal)

ax.set_title('Codon coverge for - PfDHPS', fontweight ='bold', fontsize = 14)
ax.set_ylabel('Codon coverage', fontweight ='bold', labelpad = 10.5)
ax.set_xlabel('SNP', fontweight ='bold', labelpad = 10.5)

plt.show()
outputfile = "/Users/mansi/Desktop/Haiti/Sequence_method_comparison/dhps-boxen.png"
fig.savefig(outputfile, bbox_inches='tight')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
my_pal = {"pooled":"#ef9300", "individual":"#32b67a"}


g= sns.catplot(x="snp", y="coverage", hue = 'method', data=df_dhps_fin, height=6, aspect=3, palette = my_pal)
title = 'PfDHPS - Sequence method comparison'
g.fig.suptitle(title)

plt.show()
display(df_dhps_fin.describe())

outputfile = "/Users/mansi/Desktop/Haiti/Sequence_method_comparison/dhps-catplot.png"
g.savefig(outputfile, bbox_inches='tight')
# Out:
#           coverage
# count   572.000000
# mean    105.052448
# std     224.792367
# min       2.000000
# 25%      18.000000
# 50%      43.500000
# 75%      76.000000
# max    1236.000000

# %% [markdown]
# # CRT

# %%
import os
import re
import pandas as pd

pd.set_option("display.max_rows", None, "display.max_columns", None)


data = {'gene':[], 'coverage':[], 'snp':[], 'method':[]}

snp_dhfr_list = ['C72S', 'V73V', 'M74I', 'N75E', 'K76T', 'A220S', 'Q271E', 'N326S', 'C350S', 'I356T', 'R371I']
snp_pos_list =[]
for i in range(len(snp_dhfr_list)):
    test_string = snp_dhfr_list[i]
    snp_position = ''.join(filter(lambda i: i.isdigit(), test_string))
    snp_pos_list.append(int(snp_position))
# print(snp_pos_list)  
    
samples_not_included =[]

cov_directory = r'/Users/mansi/Desktop/Haiti/Individual/Codon_coverage/PfCRT/Coverage_results/avg_cov/'
for filename in os.listdir(cov_directory):
    if re.search(pattern = "^(avg)", string = filename):
        filepath = os.path.join(cov_directory, filename)
        sample_num = filename[4:10].split("P")[0]
#         print(sample_num)
    
        df_dhfr = pd.read_csv(filepath, sep="\t")
        df_codon_pos_list = list(df_dhfr.Codon_pos)
        for i in range(len(snp_dhfr_list)):
            test_string = snp_dhfr_list[i]
            snp_position = int(''.join(filter(lambda i: i.isdigit(), test_string)))
            df_snp_pos = snp_position
            if df_snp_pos in df_codon_pos_list:
                cov_val = df_dhfr.at[df_snp_pos-1, "Codon_coverage"]
                data['coverage'].append(cov_val)
#                 data['sample'].append(sample_num)
                data['gene'].append('crt')
                data['method'].append('individual')
                data['snp'].append(test_string)
            else:
                samples_not_included.append(sample_num)



snp_df5 = pd.DataFrame(data)

df_ind_crt = snp_df5


import os
import re
import pandas as pd

pd.set_option("display.max_rows", None, "display.max_columns", None)


data = {'gene':[], 'coverage':[], 'snp':[], 'method':[]}

snp_dhfr_list = ['C72S', 'V73V', 'M74I', 'N75E', 'K76T', 'A220S', 'Q271E', 'N326S', 'C350S', 'I356T', 'R371I']
snp_pos_list =[]
for i in range(len(snp_dhfr_list)):
    test_string = snp_dhfr_list[i]
    snp_position = ''.join(filter(lambda i: i.isdigit(), test_string))
    snp_pos_list.append(int(snp_position))
# print(snp_pos_list)  
    
samples_not_included =[]

cov_directory = r'/Users/mansi/Desktop/Haiti/Pooled/Codon_coverage/PfCRT/Coverage_results/avg_cov/'
for filename in os.listdir(cov_directory):
    if re.search(pattern = "^(avg)", string = filename):
        filepath = os.path.join(cov_directory, filename)
        sample_num = filename[4:7].split("P")[0]
#         print(sample_num)
    
        temp_df_mdr1 = pd.read_csv(filepath, sep="\t")
        df_codon_pos_list = list(temp_df_mdr1.Codon_pos)
        for i in range(len(snp_dhfr_list)):
            test_string = snp_dhfr_list[i]
            snp_position = int(''.join(filter(lambda i: i.isdigit(), test_string)))
            df_snp_pos = snp_position - 1
            if df_snp_pos in df_codon_pos_list:
                cov_val = temp_df_mdr1.at[df_snp_pos, "Codon_coverage"]
                data['coverage'].append(cov_val)
#                 data['sample'].append(sample_num)
                data['gene'].append('crt')
                data['method'].append('pooled')
                data['snp'].append(test_string)
            else:
                samples_not_included.append(sample_num)



snp_df6 = pd.DataFrame(data)

df_pool_crt = snp_df6

df_crt_fin = df_ind_crt.append(df_pool_crt, ignore_index=True)

# %% [markdown]
# ### Plotting

# %%
dpi = 80   
fig = plt.figure(1, figsize=(12, 9), dpi = dpi)
ax = fig.add_subplot(111)    
sns.set(rc={'figure.figsize':(12,10)}, style="whitegrid")

bp = sns.violinplot(x="snp", y="coverage", hue = "method", hue_order=['pooled', 'individual'], data = df_crt_fin, width = 1.2, cut = 0, palette=my_pal)

ax.set_title('Codon coverge for - PfCRT', fontweight ='bold', fontsize = 14)
ax.set_ylabel('Codon coverage', fontweight ='bold', labelpad = 10.5)
ax.set_xlabel('SNP', fontweight ='bold', labelpad = 10.5)

plt.show()
outputfile = "/Users/mansi/Desktop/Haiti/Sequence_method_comparison/crt-violin.png"
fig.savefig(outputfile, bbox_inches='tight')

# %%
dpi = 80   
fig = plt.figure(1, figsize=(12, 9), dpi = dpi)
ax = fig.add_subplot(111)    
sns.set(rc={'figure.figsize':(12,10)}, style="whitegrid")

bp = sns.boxenplot(x="snp", y="coverage", hue = "method", hue_order=['pooled', 'individual'], data = df_crt_fin, palette=my_pal)

ax.set_title('Codon coverge for - PfCRT', fontweight ='bold', fontsize = 14)
ax.set_ylabel('Codon coverage', fontweight ='bold', labelpad = 10.5)
ax.set_xlabel('SNP', fontweight ='bold', labelpad = 10.5)

plt.show()
outputfile = "/Users/mansi/Desktop/Haiti/Sequence_method_comparison/crt-boxen.png"
fig.savefig(outputfile, bbox_inches='tight')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
my_pal = {"pooled":"#ef9300", "individual":"#32b67a"}


g= sns.catplot(x="snp", y="coverage", hue = 'method', data=df_crt_fin, height=6, aspect=3, palette = my_pal)
title = 'PfCRT - Sequence method comparison'
g.fig.suptitle(title)

# plt.show()
# display(data_df.describe())

outputfile = "/Users/mansi/Desktop/Haiti/Sequence_method_comparison/crt-catplot.png"
g.savefig(outputfile, bbox_inches='tight')
