# %%
import pandas as pd

file = "haiti_data_regplot2.csv"
df = pd.read_csv(file)
df
# Out:
#     par   af  gene observation   real_p
# 0     1  0.5  dhfr    expected  30000.0
# 1     2  0.3  dhfr    expected  10000.0
# 2     3  0.4  dhfr    expected   3000.0
# 3     4  0.7  dhfr    expected    600.0
# 4     5  0.8  dhfr    expected    150.0
# ..  ...  ...   ...         ...      ...
# 75    6  1.0  mdr1    observed     40.0
# 76    7  1.0  mdr1    observed     10.0
# 77    8  1.0  mdr1    observed      3.0
# 78    9  0.0  mdr1    observed      1.0
# 79   10  0.0  mdr1    observed      0.4
#
# [80 rows x 5 columns]

# %%
import seaborn as sns
sns.regplot(x="real_p", y="af", data=df)

# %%
sns.regplot(x="real_p", y="af", data=df, hue="observation")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-2f202807d889> in <module>
# ----> 1 sns.regplot(x="real_p", y="af", data=df, hue="observation")
#
# ~/miniconda3/envs/nest/lib/python3.6/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# TypeError: regplot() got an unexpected keyword argument 'hue'

# %%
sns.lmplot(x="real_p", y="af", data=df, hue="observation")

# %%
# my_pal = {"fail":"#ef5c00", "pass":"#006cef"}
g = sns.lmplot(x="real_p", y="af", data=df, hue="observation")
g.set(xticklabels=["30,000","10,000","3,000", "600","150","40","10","3","1", "0.4" ])

# %%
# my_pal = {"fail":"#ef5c00", "pass":"#006cef"}
g = sns.lmplot(x="real_p", y="af", data=df, hue="observation")
g.set(xticklabels=["10,000","3,000", "600","150","40","10","3","1", "0.4" ])

# %%
file = "haiti_data_regplot2.csv"
df = pd.read_csv(file)
df
# Out:
#     par    af  gene observation   real_p
# 0     1  0.50  dhfr    expected  30000.0
# 1     2  0.30  dhfr    expected  10000.0
# 2     3  0.40  dhfr    expected   3000.0
# 3     4  0.70  dhfr    expected    600.0
# 4     5  0.80  dhfr    expected    150.0
# 5     6  0.49  dhfr    expected     40.0
# 6     7  0.50  dhfr    expected     10.0
# 7     8  0.50  dhfr    expected      3.0
# 8     9  0.29  dhfr    expected      1.0
# 9    10  0.30  dhfr    expected      0.4
# 10    1  0.45  dhfr    observed  30000.0
# 11    2  0.12  dhfr    observed  10000.0
# 12    3  0.37  dhfr    observed   3000.0
# 13    4  0.51  dhfr    observed    600.0
# 14    5  0.86  dhfr    observed    150.0
# 15    6  0.60  dhfr    observed     40.0
# 16    7  0.22  dhfr    observed     10.0
# 17    8  1.00  dhfr    observed      3.0
# 18    9  0.35  dhfr    observed      1.0
# 19   10  0.00  dhfr    observed      0.4
# 20    1  0.50  dhfr    expected  30000.0
# 21    2  0.33  dhfr    expected  10000.0
# ...

# %%
# my_pal = {"fail":"#ef5c00", "pass":"#006cef"}
g = sns.lmplot(x="real_p", y="af", data=df, hue="observation")
g.set(xticklabels=["30,000","10,000","3,000", "600","150","40","10","3","1", "0.4" ])

# %%
file = "haiti_data_regplot2.csv"
df = pd.read_csv(file)
df
# Out:
#     par   af  gene observation   real_p
# 0     1  0.5  dhfr    expected  30000.0
# 1     2  0.3  dhfr    expected  10000.0
# 2     3  0.4  dhfr    expected   3000.0
# 3     4  0.7  dhfr    expected    600.0
# 4     5  0.8  dhfr    expected    150.0
# ..  ...  ...   ...         ...      ...
# 75    6  1.0  mdr1    observed     40.0
# 76    7  1.0  mdr1    observed     10.0
# 77    8  1.0  mdr1    observed      3.0
# 78    9  0.0  mdr1    observed      1.0
# 79   10  0.0  mdr1    observed      0.4
#
# [80 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
my_pal = {"observed":"#ef9300", "expected":"#32b67a"}

labels =["30,000","10,000","3,000", "600","150","40","10","3","1", "0.4"]
label_fin = labels[::-1]

g = sns.lmplot(x="real_p", y="af", data=df, hue="observation", col="gene", palette = my_pal)
g.set_xticklabels=label_fin

# %%
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
my_pal = {"observed":"#ef9300", "expected":"#32b67a"}

labels =["30,000","10,000","3,000", "600","150","40","10","3","1", "0.4"]
label_fin = labels[::-1]

g = sns.lmplot(x="real_p", y="af", data=df, hue="observation", palette = my_pal)
g.set_xticklabels=label_fin

# %%
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
my_pal = {"observed":"#ef9300", "expected":"#32b67a"}

labels =["30,000","10,000","3,000", "600","150","40","10","3","1", "0.4"]
label_fin = labels[::-1]

g = sns.lmplot(x="real_p", y="af", data=df, hue="observation", palette = my_pal, height=4, aspect=3, x_jitter=.1)
g.set_xticklabels=label_fin

# %%
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
my_pal = {"observed":"#ef9300", "expected":"#32b67a"}

labels =["30,000","10,000","3,000", "600","150","40","10","3","1", "0.4"]
label_fin = labels[::-1]

g = sns.lmplot(x="real_p", y="af", data=df, hue="observation", col='gene', palette = my_pal, height=4, aspect=3, x_jitter=.1)
g.set_xticklabels=label_fin

# %%
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
my_pal = {"observed":"#ef9300", "expected":"#32b67a"}

labels =["30,000","10,000","3,000", "600","150","40","10","3","1", "0.4"]
label_fin = labels[::-1]

g = sns.catplot(x="real_p", y="af", data=df, hue=" observation", palette = my_pal, height=4, aspect=3, jitter=.1)
g.set_xticklabels=label_fin

# %%
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
my_pal = {"observed":"#ef9300", "expected":"#32b67a"}

labels =["30,000","10,000","3,000", "600","150","40","10","3","1", "0.4"]
label_fin = labels[::-1]

g = sns.catplot(x="real_p", y="af", data=df, hue="observation", col="gene", col_wrap=1, palette = my_pal, height=4, aspect=3, jitter=.1)
g.set_xticklabels=label_fin

# %%
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
my_pal = {"observed":"#ef9300", "expected":"#32b67a"}

labels =["30,000","10,000","3,000", "600","150","40","10","3","1", "0.4"]
label_fin = labels[::-1]

g = sns.regplot(x="real_p", y="af", data=df, x_bins= [30000, 10000, 3000, 600, 150, 40, 10, 3, 1, 0.4])
g.set_xticklabels=label_fin

# %%
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
my_pal = {"observed":"#ef9300", "expected":"#32b67a"}
fig, ax = plt.subplots(figsize=(18, 9))

labels =["30,000","10,000","3,000", "600","150","40","10","3","1", "0.4"]
label_fin = labels[::-1]

ax = sns.regplot(x="real_p", y="af", data=df, scatter = True, fit_reg = True, x_jitter =.3)
ax.set_xticklabels=label_fin

# %%
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
my_pal = {"observed":"#ef9300", "expected":"#32b67a"}

labels =["30,000","10,000","3,000", "600","150","40","10","3","1", "0.4"]
label_fin = labels[::-1]

g = sns.relplot(x="real_p", y="af", data=df, hue="observation", palette = my_pal,
                style="gene", height=4, aspect=3, x_jitter=.1)
g.set_xticklabels=label_fin

# %%
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
my_pal = {"observed":"#ef9300", "expected":"#32b67a"}

labels =["30,000","10,000","3,000", "600","150","40","10","3","1", "0.4"]
label_fin = labels[::-1]

g = sns.relplot(x="real_p", y="af", data=df, hue="observation", palette = my_pal,
                style="gene", height=4, aspect=3, kind='line')
g.set_xticklabels=label_fin

# %%
df
# Out:
#     par   af  gene observation   real_p
# 0     1  0.5  dhfr    expected  30000.0
# 1     2  0.3  dhfr    expected  10000.0
# 2     3  0.4  dhfr    expected   3000.0
# 3     4  0.7  dhfr    expected    600.0
# 4     5  0.8  dhfr    expected    150.0
# ..  ...  ...   ...         ...      ...
# 75    6  1.0  mdr1    observed     40.0
# 76    7  1.0  mdr1    observed     10.0
# 77    8  1.0  mdr1    observed      3.0
# 78    9  0.0  mdr1    observed      1.0
# 79   10  0.0  mdr1    observed      0.4
#
# [80 rows x 5 columns]
